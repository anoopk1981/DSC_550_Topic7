# %%
from IPython.display import display
display({'text/html': '<h1>Topic7 Project</h1>', 'text/plain': 'Topic7 Project'}, raw=True)
display({'text/html': '<h1>Anoop Korappath</h1>', 'text/plain': 'Anoop Korappath'}, raw=True)
display({'text/html': '<h1>02/21/2022</h1>', 'text/plain': '02/21/2022'}, raw=True)
# Out:
# Topic7 Project
# Anoop Korappath
# 02/21/2022

# %%
"""
Minimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)
BSD License***************************************************
"""
# Out:
# '\nMinimal character-level Vanilla RNN model. Written by Andrej Karpathy (@karpathy)\nBSD License***************************************************\n'

# %%
import numpy as np

# %%
def zero_init(num_rows, num_cols):
  return np.zeros((num_rows, num_cols))

print("here1")
# Out:
# here1

# %% [markdown]
# #### To read the training data and make a vocabulary and dictiornary to index the chars

# %%
class DataReader:
    def __init__(self, path, seq_length):
        #uncomment below , if you dont want to use any file for text reading and comment next 2 lines
        #self.data = "some really long text to test this. maybe not perfect but should get you going."
        self.fp = open(path, "r")
        self.data = self.fp.read()
        #find unique chars
        chars = list(set(self.data))
        #create dictionary mapping for each char
        self.char_to_ix = {ch:i for (i,ch) in enumerate(chars)}
        self.ix_to_char = {i:ch for (i,ch) in enumerate(chars)}
        #total data
        self.data_size = len(self.data)
        #num of unique chars
        self.vocab_size = len(chars)
        self.pointer = 0
        self.seq_length = seq_length

    def next_batch(self):
        input_start = self.pointer
        input_end = self.pointer + self.seq_length
        inputs = [self.char_to_ix[ch] for ch in self.data[input_start:input_end]]
        targets = [self.char_to_ix[ch] for ch in self.data[input_start+1:input_end+1]]
        self.pointer += self.seq_length
        if self.pointer + self.seq_length + 1 >= self.data_size:
            # reset pointer
            self.pointer = 0
        return inputs, targets

    def just_started(self):
        return self.pointer == 0

    def close(self):
        self.fp.close()

# %% [markdown]
# #### RNN

# %%
class RNN:
    def __init__(self, hidden_size, vocab_size, seq_length, learning_rate):
        # hyper parameters
        self.hidden_size = hidden_size
        self.vocab_size = vocab_size
        self.seq_length = seq_length
        self.learning_rate = learning_rate
        # model parameters
        self.U = np.random.uniform(-np.sqrt(1./vocab_size), np.sqrt(1./vocab_size), (hidden_size, vocab_size))
        self.V = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./hidden_size), (vocab_size, hidden_size))
        self.W = np.random.uniform(-np.sqrt(1./hidden_size), np.sqrt(1./hidden_size), (hidden_size, hidden_size))
        self.b = np.zeros((hidden_size, 1)) # bias for hidden layer
        self.c = np.zeros((vocab_size, 1)) # bias for output

        # memory vars for adagrad,
        #ignore if you implement another approach
        self.mU = np.zeros_like(self.U)
        self.mW = np.zeros_like(self.W)
        self.mV = np.zeros_like(self.V)
        self.mb = np.zeros_like(self.b)
        self.mc = np.zeros_like(self.c)

    def softmax(self, x):
        p = np.exp(x- np.max(x))
        return p / np.sum(p)


    def forward(self, inputs, hprev):
            xs, hs, os, ycap = {}, {}, {}, {}
            hs[-1] = np.copy(hprev)
            for t in range(len(inputs)):
                xs[t] = zero_init(self.vocab_size,1)
                xs[t][inputs[t]] = 1 # one hot encoding , 1-of-k
                hs[t] = np.tanh(np.dot(self.U,xs[t]) + np.dot(self.W,hs[t-1]) + self.b) # hidden state
                os[t] = np.dot(self.V,hs[t]) + self.c # unnormalised log probs for next char
                ycap[t] = self.softmax(os[t]) # probs for next char
            return xs, hs, ycap

    def backward(self, xs, hs, ps, targets):
            # backward pass: compute gradients going backwards
            dU, dW, dV = np.zeros_like(self.U), np.zeros_like(self.W), np.zeros_like(self.V)
            db, dc = np.zeros_like(self.b), np.zeros_like(self.c)
            dhnext = np.zeros_like(hs[0])
            for t in reversed(range(self.seq_length)):
                dy = np.copy(ps[t])
                #through softmax
                dy[targets[t]] -= 1 # backprop into y
                #calculate dV, dc
                dV += np.dot(dy, hs[t].T)
                dc += dc
                #dh includes gradient from two sides, next cell and current output
                dh = np.dot(self.V.T, dy) + dhnext # backprop into h
                # backprop through tanh non-linearity
                dhrec = (1 - hs[t] * hs[t]) * dh  #dhrec is the term used in many equations
                db += dhrec
                #calculate dU and dW
                dU += np.dot(dhrec, xs[t].T)
                dW += np.dot(dhrec, hs[t-1].T)
                #pass the gradient from next cell to the next iteration.
                dhnext = np.dot(self.W.T, dhrec)
            # clip to mitigate exploding gradients
            for dparam in [dU, dW, dV, db, dc]:
                np.clip(dparam, -5, 5, out=dparam)
            return dU, dW, dV, db, dc

    def loss(self, ps, targets):
            """loss for a sequence"""
            # calculate cross-entrpy loss
            return sum(-np.log(ps[t][targets[t],0]) for t in range(self.seq_length))


    def update_model(self, dU, dW, dV, db, dc):
        # parameter update with adagrad
        for param, dparam, mem in zip([self.U, self.W, self.V, self.b, self.c],
                                  [dU, dW, dV, db, dc],
                                  [self.mU, self.mW, self.mV, self.mb, self.mc]):
            mem += dparam*dparam
            param += -self.learning_rate*dparam/np.sqrt(mem+1e-8) # adagrad update


    def sample(self, h, seed_ix, n):
            """
            sample a sequence of integers from the model
            h is memory state, seed_ix is seed letter from the first time step
            """
            x = zero_init(self.vocab_size, 1)
            x[seed_ix] = 1
            ixes = []
            for t in range(n):
                h = np.tanh(np.dot(self.U, x) + np.dot(self.W, h) + self.b)
                y = np.dot(self.V, h) + self.c
                p = np.exp(y)/np.sum(np.exp(y))
                ix = np.random.choice(range(self.vocab_size), p = p.ravel())
                x = zero_init(self.vocab_size,1)
                x[ix] = 1
                ixes.append(ix)
            return ixes

    def train(self, data_reader):
            iter_num = 0
            threshold = 0.01
            smooth_loss = -np.log(1.0/data_reader.vocab_size)*self.seq_length
            while (smooth_loss > threshold):
                if data_reader.just_started():
                    hprev = np.zeros((self.hidden_size,1))
                inputs, targets = data_reader.next_batch()
                xs, hs, ps = self.forward(inputs, hprev)
                dU, dW, dV, db, dc = self.backward(xs, hs, ps, targets)
                loss = self.loss(ps, targets)
                self.update_model(dU, dW, dV, db, dc)
                smooth_loss = smooth_loss*0.999 + loss*0.001
                hprev = hs[self.seq_length-1]
                if not iter_num%500:
                    sample_ix = self.sample(hprev, inputs[0], 200)
                    print( ''.join(data_reader.ix_to_char[ix] for ix in sample_ix))
                    print( "\n\niter :%d, loss:%f"%(iter_num, smooth_loss))
                iter_num += 1

    def predict(self, data_reader, start, n):

        #initialize input vector
        x = zero_init(self.vocab_size, 1)
        chars = [ch for ch in start]
        ixes = []
        for i in range(len(chars)):
            ix = data_reader.char_to_ix[chars[i]]
            x[ix] = 1
            ixes.append(ix)

        h = np.zeros((self.hidden_size,1))
        # predict next n chars
        for t in range(n):
            h = np.tanh(np.dot(self.U, x) + np.dot(self.W, h) + self.b)
            y = np.dot(self.V, h) + self.c
            p = np.exp(y)/np.sum(np.exp(y))
            ix = np.random.choice(range(self.vocab_size), p = p.ravel())
            x = zero_init(self.vocab_size,1)
            x[ix] = 1
            ixes.append(ix)
        txt = ''.join(data_reader.ix_to_char[i] for i in ixes)
        return txt

# %%
seq_length = 5
#read text from the "input.txt" file
data_reader = DataReader("input1.txt", seq_length)
rnn = RNN(hidden_size=100, vocab_size=data_reader.vocab_size,seq_length=seq_length,learning_rate=1e-1)
rnn.train(data_reader)
# Out:
# iealMRPLMbayEPyFod.s,zLt,svDddrV.'JLH:bJ.M!!bInkNez:iI!-T,xvJPbF-lwtuFGF.TGvdsip.HITst?hpz!JDdiyWeFNjssgCqcxh,g''BJJ'IjflLsc!PzkUj,'OsPIUMhOItfpBvy?xsdB?uzsNshLirs?REqPTgYYamoJmz
# fVftFsTaRo-esjoHqTsLs
#
#
# iter :0, loss:20.302475
# hoed
# i,e ikhwhodwtCa.awaitehie wc:e:ttsaon on ehse
# o bevnsrn ens
# hnhnhRn e kwMsennnys a oo
#   aunooaoutn
# invb,atisid
#  ielte seeigbhw.estYhnoeCtiswli ulaingkoa  ssebeywth wboyottb  er yoyy kokdyakhusd
#
#
# iter :500, loss:19.707176
# drdgs
#  ,she od hur ctoisd .o,relFhck etole watee uuiewhioof  ie lo'nc reemrilaod hul tnhelseA eear
# mishl ota
# vro, hslt:Colmhv urel
# jmlasn Tey ttsvrkl iah nyheail huthlFwst baitamrntEaoo
# pvle s
# elunc w
#
#
# iter :1000, loss:18.418209
# or yhe  aimxvsta.e lyon:
# HgRhers
#  My .ee ca, zohrt toIe! air
# tAiC;n gortnveae Mhou tac s. U.
#
# Hose cteWvnsr:
# HithnS Inn mCorge bou aed whe gou oanl, Aa.r
# uI
# Fottolepbpbouocny
# S;
#  it fatraunU
# BRhhit, g
#
#
# iter :1500, loss:17.282144
# rl wead ltey'v fswat whn'iNIRgo: wileteas iteau? iMnklVn
# AEAS,  hla lbylw mhn eiUo:r
# EW
# bgoipemsuit
# thtot onns sclon kidpNthAlre coned
#  cee, t roy wy re,IR
# U,Fsrmshd iaedn mnac whoo nov ooued th!nes M
#
#
# iter :2000, loss:16.246652
#  amesteiss hy nome bod h ut iret  hct fe mainr
# MCrd mitds mhotr don eocs tcilkdo asnt inr
# E'
# Iail teeirse min o., riuw h , kaur, goo ern e co mcf bo.l bounthe teu se slie mirl,
# O'rn.
# wCnr o! thits ar
#
#
# iter :2500, loss:15.505731
# n morttaminh arroud prelo'nne cer minesiblIe
# LOd ti,, benldttagsthe whare wics
#  paueoryd omd, lsd honr. ta whos Sins mod acer bowe reed yonusc in whe isrcte au ittoethaly yhein, nyouss:b thean wo erne
#
#
# iter :3000, loss:14.825232
#  ganrr:d; god ,n yheo' a to'ths tounegnu
# b!nny halma'ns hogs yang
# rutihe isin
# chays
# Hosrk
# Lou hatheen'gede
# pit told ad  hnar, the hi, ;oul anrel
# Ofore hed'r ; thigss reame tfoaIsiagaRg hri.t iat,
# nrz
#
#
# iter :3500, loss:14.494882
# :
# A:
#
# Foomdv me co tiz.
# , wes thes:
# vuos rot. os che ,e C cis Crttzs
# CTon weurit Cot yvit n;
# Ae home
# S,:
# nhitaom.
# :
# ? ths wo looy :
# Mi?is
#
# NWd sn gos.
# ; Opas trare shcnh wCcmatoret zeimth.
#
# Seris
# deis
#
#
# iter :4000, loss:14.050604
# yaE, Cenl sit idr'eyt, youkawe, C leel':
# ''rr yhetiy yind, kelrothely.
# Ying,Cs unay ath nzatirs arslthe fid,, Cadd , , bohe phethet fLmowiithor fhethe, toar, wsret bell pcev'
#
# NfLr imd
# Woi ureinpys Vl
#
#
# iter :4500, loss:13.641864
#  many sslmmalill theelbymif nrtt what zysit'd Thet chot asd, wolsIy
# WatoNfat;
# Yhhes me tey the aenes the moron:
#
# Foit hed beokiceigad anm,
# wis, Aerctit waplel:W rnr, ang the melm 'l to gsre thmoud yis
#
#
# iter :5000, loss:13.088090
# y
# Vfrche onst and mith miter the-noor.
# Wher and, The fhapeitinwt ol, arbs, Caagurirreesimt man he of thery,
# LSus
#  n,  oud m pingdf
# wesath- mryith wotpou thk; that yot th ve theseg tebouth
#  hets ang On
#
#
# iter :5500, loss:12.840308
# s in: l, huld!d
# bf
# CiNI'U:
# Held Ad. dol
# IoS:
# Ak t as ars all don: youlnedy Fir tocFomd ys,
# mhino Iausin--S, zopnss
#
# INNINIUSI
# S: sre
# ; Topfs dok,
# Whe dit whe,
# COe had tuoanthe
# CSMes,.
# whs ;sr po thadt
#
#
# iter :6000, loss:12.712344
# me ore ore to anse dantt
# RIr.
#
# S: , dotl tiil !frhe wano srttf onrinl mere iu.
#
# AnNIEUSu: sal.,
#
# CRELP::
# IUr
# CAoRI
# IUUS:
# MAl:
#
# Fors
#
# FTaviwcwanok Iie foy, I porrer .e
# The is puch inslno
# onE heycey, wa
#
#
# iter :6500, loss:12.659376
# s in youde gimle:
# Vorcene  oout sarse and why ban if, wo eolgo eis in seds hes bre.:ad fo foRkI hes: hees, wids, yo ay tou Coud torses be, heet foompscew:
# Vil I gam, Hercee pomse, Iiwe bok than an tou
#
#
# iter :7000, loss:12.673401
# abpeginibapn.
#
# VIAL;
# IA:
# Awergoules
# Ca yait Shrin
# I ietngety hit wicer ciust mesipk y madgy,
# yone,.e piy ci mitote- paggit ind coou: tott! pifss mowewas:
# That ersithis k wore yur'tit he he orinked yo
#
#
# iter :7500, loss:12.532228
# e s it fheapbars rotpey he youy,
#
# Five dfylousine,
# Tovem,uty than, lutisd y
# uvau phe irsm at, avote ti; ap r ure or ars. meverel?iteps parousd fearsans in
#
# IIATIO
# Ping doute moile tu ade
#  y'y misr wer
#
#
# iter :8000, loss:12.324512
# thinde
# kiplmy Che ar!
# Wually th goth  Ibe,
#
# Falo mhoct the bont arrs aal aaesp bpsasei, hnce srois ted agere keunn w? fhon momzhti
# MwerNN Weuve th ece yo geltizeelildrac, Wre coy yomu'
# Yat re  tonl am
#
#
# iter :8500, loss:12.013143
# zS ceaaf pablen-t Wh, aos mialdst
# Bnl Lal soll watis she vel ons hit.
# Whey th wey fore mikvth siegr ook, the euly
# That doud misal!
#
# MLELUS:
# Who ind.
# Wheneeds,
# Whe whallond enit ipit pind the the ital
#
#
#
# iter :9000, loss:11.869032
# nore, uper mgoll-ln
# NIUS:
# TweOd 't'm mr o unk foe Jr rand tuallsw
# MMAR
# WkjOuus,
# Os ir tor asd lan, phaws:
# MIIR:N
# IUS:
#
# OuRh.
# Whas thas ar bokinbt cicoun
# Far thond ror.
#
# MORIUS:
# An? thansn;
# OI Lod nsth
#
#
# iter :9500, loss:11.848568
#  ie torule Ae frell,
# Tuu:
# Soreedeepandees, touces toW?
# Whecy'ob? Rou doweafritinis MyowinS thety oo,
# Toures. bollr
# Sove mindes miess teell tyaf wat or atsey':
# Whelad wiondig yeanw Lery RageranC.
#
# TIEN
#
#
# iter :10000, loss:11.850212
# ast whly an cti esc brow cenom, thiriof, or souter' oo tellad.
# Iellc'te hith wine;
# Bk:
#  esh jowwelle,
# coad mawin H wemlme weh hof Coas
# Aud manth hie irciger ereus ve ou bunu hot Minoles dgours  ma man
#
#
# iter :10500, loss:11.988050
# ivat Nafir iu tayss wins eravefyor ou whodthenken did mieher.
#
# IRWhice
# lave chee thismored.
#
# Sith
# ktitg pey fourize
# Or in
# Cid tunt.
#
# VIRCofelit eo'd hic thar wik shicf thatyv: at; afs ort
# Acpen;:
#
# O
# W
#
#
# iter :11000, loss:11.985031
# n che tikito yore canlon gir
# woad :s apropras marconepsed oomniSfo aste.
#
# S.
# NI Ie, -iad irt, eopaey
#
# farith -imy faor.
#
# Farc fadims bederthe conkocon!
# Whey artthishs tuint, faurgore, dilas sslmy and,
#
#
# iter :11500, loss:11.800045
# ly shand be s, so 't wat; bonent't you in dily
# yo' nsed the dett ens?-
# The rered, yoree?s soert'ln
# Hes,
# anven'y ats eamond ceith ney mother berts lant, the vellmenginct; hemongefthacsd aldestamilde r
#
#
# iter :12000, loss:11.549381
#  fole hant'-:
# Wheese yo-e shary
# That Mot wher!
# 'soow?
# Any
#
# BANNNNU::
# YWhes egetheDnge''d ot gookend wis
# Thatpdind gave yromings ar thtbece that bam rite cove a;
#
# VoERSS:
# -faer, liby pesiset, he Cor on
#
#
# iter :12500, loss:11.384541
# nm or poRm pil powt thes.
# Dhan manse;
# Sease, ha gours sef aro mlaac'cafin cue toall: urlvon; thow sawe ure fir',
# Ay thes Wous!
#
# MArVI
# MIA::
#
# Foute! ir nour! is.
# The mirind
# Tou
# MBoNIY:
# A: as.
# Toonum.
#
#
#
#
# iter :13000, loss:11.447741
# emway ,at oukh eroth
# I'best ban the thit ousisd
# shesevend,
# :em howe thithendin
#  heis aien, hith anf
# Theiesty hume art mordat.
#
# SIL:
# INIUSAUS:
# Whes we fitfo tith pitgrign:
#
# TfRingon whe tithems at
# Salp
#
#
# iter :13500, loss:11.408594
# you shes,'d romy yor link ou! us.
#
# VOLIOP.;
# -enlew
# Word'ly,
#
# Aapde acud;, I reitche sher somars Le fifius pom he brhill wifiel dow theminiit
# Thing ta curod epre lroll rin in; thand you'y the you yenze
#
#
# iter :14000, loss:11.627102
# .
# E beist ard avey hit undiler; me fourer on itiupthed;
# Tuth
# wethen weald sthet bumete tolut deratt Ous me wtonG titl cithas, cort he bisp; mell, inge.
#
# A, fey
# undem sberlis s tatour twoth ceate on co
#
#
# iter :14500, loss:11.728045
# u, , and eit hath mrondes he! sirt thon the fou dantinit ,
# Whiaghee.
#
# Freartstwin'dsrcou ha ondt tout't Cacowdselne:
# Oy you pit.
# Wevis Mac mowd, vatelwiy inetithy nogt elthes,
#
# AtsyC: at wen.
# Nirt bed
#
#
# iter :15000, loss:11.515866
# moy. Thanp femeicenh the tore thotr:
#
# Sheit iu?s the'The hisn?
#
#
# FENENIUS:
# 'onl bes,
# ofionm loppit-?
# O! shes vear; Iob?
# your tellel,
# Tuijs to bayize,
# cond prescon?
#
# Sous, elvandater.
#  ullest blan fre
#
#
# iter :15500, loss:11.331509
#  vigh,
# Yoursen: pof srson; Iou cllelrs that t purogl as he l wirkiesis as ing your eevt'
# To istey you ive.
#
# Toudsse cit Ca ivet urt rmith shy go byr fof ivacilibst hee slamiged bobend wolb en ca that
#
#
# iter :16000, loss:11.147259
# ouns'y
# Anad llgile Wire mipf
# And Geal ou heren:
# An tht oa, thit and nowin theno and  tila bverne and miriou, at. hiwis won the rely
# Cy bercoy
# Whe wauk, en ith
# They foa on st wetein.
#
# NAry
# I wove ant l
#
#
# iter :16500, loss:11.156003
# fank. whon, I
# Ofe;
# Youry he ou
# Sebupy anom he ?bed hiv is shat  hen?
# Wert, oud sh ould Loll of and ghe sathige fong he pal! ,
# Thand, and yd biksn Cers whorr? arededicet?
#
# Serowe,
# I I found woulo'nd ir
#
#
# iter :17000, loss:11.176395
# e rud; arrald whee., 'pcorad.
# Whas fol hinth rer ssors ond onoun boom o, men shery sene bed n py est'y
# le,  tering and wonettwe Swen igivakes
# cun kirepld, ssond hhite somcor Vamismiuthar:
# Heid bang
# So
#
#
# iter :17500, loss:11.296815
# ans gimes en, opingh hotre nyoo hon wove vor naker as celth,
#
# VIRGy!TIA:
# Then; memt opiR:
#
# VARGTVIUF'-NIAIA: Ho haciot hey walld igr in!
#  opid shelyt fenred pit rren
# dendere mank it,
# Ud uhicitozer: Ey
#
#
# iter :18000, loss:11.384389
# OA?:
# GCadent, wast on do-s Tejucon; hou thany ande oflllinir:
# Lun: stis yours- coronm hir, ind the pelrate thes, wart wrinsd
# And to mate weith thed:
# Weniin bn.
# Andcey eanlan: bere dor sedamout. wheing
#
#
# iter :18500, loss:11.207487
# alomtermys muse faly an tay
# MIACIU:
# Fnelrother thet
# 'Itthe pin iu
# I Sote much, In
# Oon te, veitiky Matizn
# Vitfzent one beanecer to wen the mincsenothze she. ste loundiug ir
# Con hus bopre to ther arele
#
#
# iter :19000, loss:11.128738
# s m'rer the peaaks.
#
# MAuscvetrourte, for thit wic thurtethaten: Myo youre thong at ie amionrourt, urk dathiwh Whoy irng arpis, enour-st toy ure' whit tize no cot urce you,
# Thelly- sulvt gare, Ine hit
#
#
# iter :19500, loss:10.811504
# ttound poust-f kauk meags whe thaner the pesy chesukit
# Wheale nufniy; fousurs argeration bemger'tsty hathys dninepr,  por 'n wiches iime she mid with ith myung ro go armut:
# Tbapth:
# The girtingens dast
#
#
# iter :20000, loss:10.894244
# he bupiut on,
# Coull
#
# orCIUS:
#
# VIA:
# rxearing: or you thecande sous than heint, bulisiut reniande dot hage pirt,
# MoL:
# In Whir tho' fim ot and hacaf, co peafe'e ins
# Whan micand we thar war, they,
# Thaoust
#
#
# iter :20500, loss:10.886956
# are wat, rulved hanse ingt whounw.
# That weale the cheel, ass ow hon
# Arpowi heer
# Sealan the.
#
# bamsicou yul barsigh the weake vand you
# Your, of if mich they word banou ef and un was ha!oulk at,
# You if k
#
#
# iter :21000, loss:11.028231
# I
# Yic shebrea; sy ho covluf toe darsan arvron: 's iuc,
# I wonge he thith oogco hep ans hamk ou ank; whes!,
# Werad he ituer
# wuchie honde.
#
# Vidh'y
# Shat the apanedy,
# Whelis dath to
# ron un, warn:
# Fath antin
#
#
# iter :21500, loss:11.216282
# h; Cangit the wook; hinsen lits one win
# Yen?
#
# Bey-us not Caall goatith daperet.
#
# Sizand nome noutcow: sitor!
# CI I cothe cenaous yoof?
# or hit to shons cort 'het. ante?:
#
# ARCCalbes, ofr thercinestt foti
#
#
# iter :22000, loss:10.990490
# mat illy to
# Bill-d.
# Tursed youly ei galn.
#
# Firts voud:
#
# Fibithe with litizesty
# Fors tud inker C.our thet wi mbarten
# Or,
# Whoncen May f irs enons;
#
# Orrig? way.
#
# Ar: Cirl lontul:
# The fit Send dhess whe p
#
#
# iter :22500, loss:10.916839
# ti. goast;s:sestall
# A:s,
# Hadtolldizinsug velrs;, Sengcelret sriat.
#
# VIA-NIUS:
# ; but dot ait I'd
# yout.
# goe mand this sore, as is the sat Woze hand, fot, Citis the bame
#
# MMENENIz:
# Hust gooel:'t thens te
#
#
# iter :23000, loss:10.633276
# d anvigs aybus these so pand tho ghith indst:
# That wit then your hould and tTratinstU'c
# scoma kall, wirenbefoppangee
# Wham st lom;
# Anese,
# Shey ming on mite at. andeer wather ite gor thtracs arlll. wore
#
#
# iter :23500, loss:10.691794
# ancould ster: I bene fil foowmt,
# That ram ' ass thins.
#
# VIUS:
# VCidUS:
# Ngom me mort!
#
# Frarg ants fowm gotis
# Thed hene hull hit thepl we iv' afcen yflen:
# Nuve dichen, peattu, the rive wavins the bou,
# ll
#
#
# iter :24000, loss:10.647163
# atcor sasd frang. To e noust To berle po susmafly marf shant Cat you fearedy gormyof lorcemuld discaniobst ereloe, an meathing, foong wirehonou he sh senlus plopde wir
# Onge sywe Ae rame id:
# Tor:
# Ouc
#
#
# iter :24500, loss:10.738972
# :
# Winhe domerad ing, dis MoRthe vhie seis dit ho ssall now mobes, on andstyas  gere bald in donpmrs pou heyg in trounty he are, Vare mans rerer fit centhous hatis. toud seay anded.
#
# VARGIUS:
# Ne.
#
# Vmiy
#
#
# iter :25000, loss:10.912431
# :
# You it'd eincinby: you givese' tizy
# Ou chaced tin breside puit. Woulat th if cerie the benin no plowe as how toeepy,
# I ant bn, ius con'
# Ar danin whay, you this wor ines,
# Thuse: poon dot, shat' lary
#
#
#
# iter :25500, loss:10.826093
# ius,
# The le uresld you
# Thel mepealmus, sy toughe kirred I tome o' lidme, whit dey oan fatplais!
# Youl fease peapfiuv.
#
# girstst move uss't I is
# word ut; shour hikt inct ar bims; -or c, ofll-st waee-wen
#
#
# iter :26000, loss:10.737523
# t ceart grras and you,US:
# An chor,
# Whucsine bestes cong,
# To und ly I loon
# That to
# I mevenk ? lell, the med is chat Ir allr mal's they dor mhey yop helly, heit
# spadit and bebid becund.,
# MMENENILIA:
# For
#
#
# iter :26500, loss:10.469683
# A:
# I lyou, I pres aig baphre, ands fibkeses?
#
# MERCILIUCIA:
# His.
#  yourt tyre heter; ace
# Meakly Iavat't -'pin: or andes rede the lat blove math in they thas agope vint's port Hith.
#
# FiRst of waus;
# Wuve,
#
#
# iter :27000, loss:10.466405
# :
# Thet of thnous.
#
# BR:
# Who ! this Cor! purut; thel the fit or ad bprond, the me-r
# Audy.
# Yhey go bbits theborst?
#
# S:
# No ghat
# Shou!
# s tou the becin;rT; farns ermes 'st lis aighy ven Cor us thusanthisiss
#
#
# iter :27500, loss:10.448157
#  bopis homy dorebe,
# Whisceked of lyselk ale:
# In ar ou cod venced
# The buseirslt Sit ir thild; bay
# Tur anes randes they
# Ueng ressed wirese wave Sor att lortinou,, hav att.
# I, buswar dice eik' tere aldye
#
#
# iter :28000, loss:10.540862
# r
# Fram thang. reale gie food, hinds; and the, for to wo mtsall ofeld
# I't onl Ved imne purgy has wongs woule ow lsall!
#
# VOLUMNIUS:
# Biet, shan momwen;
# sVinte haed buct than whoug vord cotmbourpresnO ti
#
#
# iter :28500, loss:10.742282
# n, Cowse thiy yoe  to Your is nst st becit che mectacketsm's.
#
# MARCINIA:
# Lell Cesens ise ares.
# 'Fitneld hith, to kave batos'y our hit dere hing Irtirdt, butte.
#
# Sere id; stisese fatizeve weed you nito
#
#
# iter :29000, loss:10.679720
# mert,
# list, potry parl whom; in suatesranded helar honke; bine, act: aclusdtione, you.
#
# First Condicl cotretfsorse stir coy tire suportund.
# Be foy mularsest younds, firnd witoren thases; sonm
# is ee,
# T
#
#
# iter :29500, loss:10.544054
# 's;
#
# first o the gomediks shenencbnnest, hist shao'd aven buond, that, tin mey hienctve whertu, I: wave buat.
#
# Al:
# Howe iflinst mit?
#
# Fir pein-g, the owe swanition ghir.
#
# CVENENIUS:
# Bty he heithen?
#
# M
#
#
# iter :30000, loss:10.352038
# ber, bopris'dsks
# Tarese
# Thoy thece fits snol- cith?
# Wheid; ta bend comd you mloudire oly in
# Feacous to lisly of. gpeandet yor ive Fa youlis yat tuth gare, poob wecit, thoke-d to leanmsiy, Hey, Hice
# sa
#
#
# iter :30500, loss:10.261130
# m.
#
# VERCIUS:
# I Corm san heme.
#
# MENENIUS:
#
# MENENIUS:
# Hecy. wip us, toutWend harp at, ere wilnt.'
# elt ous.
# Weys thet Maoder, yougay ke arc.
#
# MENENIUS:
# Wiche-core das,
# At.
#
# First Certepldd; .
# Tuuth
# hiund
#
#
# iter :31000, loss:10.328119
# one.
# bus bart It yot,
# Theismis ment oad: stend at ares loongsouner on yor foratet betet yould anve or of, lenoply
# Oussrs,
#
# wider our turt erdweb reius to the feant.
#
# MIA:
# Bat shius fhe thes llow he mu
#
#
# iter :31500, loss:10.341803
# you thas,
# And that oud whishwer i sheve sill ave qrirh kould dremibnt I choyd
# Aref thes in do unde Whom ou- cre btinc.
# oor a mes. I'd henon hies adliganc
#  with gow Blse bran
# marr
#
# MTRoLUS:
# Hease weta
#
#
# iter :32000, loss:10.581739
#  hor
# he peat is
#
# NarRMIUS:
# Airsirn that aet.
#
# As aun:
#
# VOLGbind
# OL is arow wive kike the tird in; seio't
# Balt I thank leareak.
#
# First Cimd than to atorly
# Fundltius tpeme bremont the grod
# Vwareit
#
# Vifh
#
#
# iter :32500, loss:10.605489
# ,.
# Heer th yhe rat, nowe, rear insers, food emint anopleses arf turaed nappicor the cereris age, benonor:
# Yot:
#
# Be mong
# Manetat in I becath you hall ante, for Chat to intert woor til the die
# Ancunsus
#
#
# iter :33000, loss:10.350036
# stizend;
#
# NoMELIUS:
# Fitt I thhiseld er allllly Apott, I pet heeches lithis haritet!-
# Whef is pitizen:
# fure what I timt Ro ce moud matt the on sith you met leakt we.'
#
# Farsth. s, they landy be,
# To matt
#
#
# iter :33500, loss:10.241009
# herer your for?
#
# MUS:
# Nithes fhes art rilly reastonie mey uns you non tive Mins thon wus hade debd the diseDs tusselly yiurderest Cith ranst whare? hien aleof?
#
# First Camly the hane that
# Cace misd tfr
#
#
# iter :34000, loss:10.131561
#  whools you time't; eak?
#
# MOMENIUS:
# Ho wholl mer in the laldesres,
# Wit allicith setis: farst et raler'ts hed gory
# Sell
# Mis I le laki, woud rowye, gre'r'me hall touk torg tad igf is they they dives mat
#
#
# iter :34500, loss:10.240287
# nrath trerus hepaund hotar duot he pod , wat th, I mate,s asthy yoMy
# So dall tt the
# core telvpst.
#
# AUF:
# Chom chons goor oe st wsor ghat Eone hime, gatn.
# Th thCer ayt: iun and tet coufpault
# US:
# Fousir
#
#
# iter :35000, loss:10.217693
# ipin homes the marcan wall en he wund alfed hears reanit belie mreind heilibepCener hat the pomme fearich and in to the lyrlund
# finkrelsott cooll mal wen
# Tomer coustonon seave ,
# Awdand woury ow chat w
#
#
# iter :35500, loss:10.402502
#  ardirs.
#
# VARINIIA:
# I hit, you he me to kats op rom en ids. mo
# I thin subow hish anligo mu nit enk to mes lofne shepread,
#  sor:
# S:
# Marik
# IDIsA:
# Alm lyoree.
#
# VsATRIA:
# Gosmagrheland wou't-or, the hid ho
#
#
# iter :36000, loss:10.418383
# nuth intont riy wine thius
# Couge ath? I wead
# Codiwest ofe boadc?
#
# Filv!-
# A; noudon.
#
# MAR-IAth let ther araver: is I pols inst; do geate.
# leine so veik
#  you trant intt,
# Yous Cisthe hich by the seanier
#
#
# iter :36500, loss:10.234508
# r tis Rheed Whom me ast the mirmwellesce ater Turtere,
# Wheec.'
# Whethor,
# AT lel, hiss cotmend
# Ankes,
# AWtthen,
# I beres?
#
# WIll:
# Whaus
# Hanchy:
#
#
# FREUMIFICNINIUT:
# You lumpor, muter alabnnte: Rare wit retks
#
#
# iter :37000, loss:10.160692
# utre the rone the poumer on
# Ron urcy
# Weatill,
# That hartet! Mtong, halleren dits demsius romer, the aghing doxlriusus;
#
# MENENIUS:
# I prem? pow
# Anse tall
# On,
# You, me uster?
#
# MOrUe--Hy ther Ar,
# dreve lala
#
#
# iter :37500, loss:9.927184
# nd the bengopf, on 't wiurse thes bee!
#
# Thess: is file. Youn werall shat led gos as gored cond,
# She theith taunsp: the ro
# mare,
# Fir mong I rid: ingrt fird.
#
# MENINIA:
# Shater Alase well welanceCes
# srvee
#
#
# iter :38000, loss:10.122773
# ris, Se vore foedcun to puporwend on musaave lyoe' pot the Cituand youn sill eafecan? buche nom he.
#
# First, on gors goont he chas, I
# Ow of in homer anIst, go stonitlond
# MENENUS:
# NENIUS:
# To leald
# Mecfi
#
#
# iter :38500, loss:10.103004
#  thicesl thas his fath lit ;'y heeld won all we madlen awemefwend them, to kith lens and cuth wo koonson go storte, wo keam,
# Se arse secicuste, th nger hebecy dost should now hough oow whe centore,
#
# A
#
#
# iter :39000, loss:10.260151
# f ot fibdey
#
# B-pLaid, do mpotou
# The arin wour wh sunounf lo ut; ''nserdr hing,
# Thot rathen, be you soue.
# Bhat yone hall gads you bras; hody that witse aepan.
#
# VIRGIUFA; warograch andsed this as fou th
#
#
# iter :39500, loss:10.387690
# e gronf you Heopde
# The rant you he corpangse
# noou, ses, the hith anr ilss, Ciuk lellbout there.
#
# IA:
# Wearcelizianf; took?
#
# MARCINIA:
# Non: ind badinot not hil corecous.
#
# First.'
#
# Sicst Ca coud smont th
#
#
# iter :40000, loss:10.137563
# alliand coth min thon. chich id
# Bis, be my you,.
#
# Fill mumesces
#  shan whe bee yoo thes int wend h t habe aitizen:
# I'd
# Thot Int I beass fie the dim ppomiis nit frat er cett. goung, and engeve fin;
# Hesm
#
#
# iter :40500, loss:10.160608
# ust andy: toon bothar? haon h himbese sor esed huther beces, ware
# Ontoucius,
# Yun metithestancinst
# If I couthen:
# ;o the whak fiancous,
# Fiat:
# The piister, mavisad'd all yof the frit.
#
# BR:
# Aetoro, Viffwe
#
#
# iter :41000, loss:9.862694
# s wadl gasd minouy efecir yountouod
# Speriund
# The thay cours.
# Thet wide mad if theh thene twant's?'
# flesus ou witt: no think efy.
#
# MENENIUS:
# Whom lrake'n
# To d moinge andend pountay
# Hece casd cors, fomd
#
#
# iter :41500, loss:10.010285
# on ceasccong.
#
# MENENIUS:
# I't ards coudser mill.
#
# Firth:
# Whrmon, arius staliet,
# Whe home apen hemas qrey,
# Whees;
# We cst ly hor ople tell ill Cith stan bathongred akl.
#
# Firsc 'pfit Seesaad agd the bes r
#
#
# iter :42000, loss:10.034197
# rw the corl dowy?
#
# VAR:TI I moof tay wounder thacs lour hee on'ds you pring date of so thant thair,
# Sanes in as whiry sepedcideans.
# Whom whayUSS: pors a ricis, nou wei:
# 'nutefrdy waistof.
# dous fauches
#
#
# iter :42500, loss:10.066536
# ch obepon fot thished pive no lauu.
#
# VOLUMNIA:
# Se and youldedsols bed on co'ngrenrcerell mimowe w'und geeve nour p,oll. ghe cead them unsitoel los of; dow nhe rowiing; ay in coush nod hie lrontius hio
#
#
# iter :43000, loss:10.254417
# ou, trandst thice dalliruntor:
# Horpmlour, oune court nour you woJ, thet ipans that I thay tolly?
#
# BeRIA:
# I'to to and on if thous
# Su shemyst ou',
# Eell hant, in als,
# -on calce 'heay.
# Whe notoencery.
#
# ze
#
#
# iter :43500, loss:10.113089
# y
# le, I
# .
# Your your fotas,
# Wite wall yoor: he reabl,, ysw hive tored lely ande, whel in maont taditizen:
# Learse
#
# fiild we a rithes anitise for fits a lally stered thre you indous, your, you unted
# you
#
#
# iter :44000, loss:10.091120
# ; khaneweld and meith natus.
#
# LERCENININIUS:
# Whe besont whereest core wat that w'tin:
# ghe arcichmy'
#
# First Cath.
# 's to iat, iusage inghin; mus, daiprt, the buke, ay. fho hall, I
# Oflmomy syou the moy w
#
#
# iter :44500, loss:9.790355
# that mutizes aredCacg, Uqbags your sude.
#
# O IDIUz:
# And.I ta, thay
# Then's thouksy
# As Marn thom that pact, hion; and
# Lins, that apre's that that farllod:
# Woukdsito the otrtor,
# The Cart, hinivut; thoull
#
#
# iter :45000, loss:9.883526
#
# Aspen to ur s: you gill me pryouo, woms thehel-,
# Bome toadd ow tham yours-cauns ste, besed:
# Or potell ius is won:
# Whicoor hese.
#
# O.
# ?' guld the stales mand wouliou,
# Ifcfyusut could;r.
#
# AL:
# Couaunins
#
#
# iter :45500, loss:9.809044
# ve
# Hat, you wilis. I beay, you snoog'toar!
#
# MNENENIUS:
# Tha beyou have me kreaf silenily your:
# Hete your
# Mord mave wor doon! I
# I'd anduded tis thous kanrtiwhesend
# A
# AFend dit mo fands,
# Mailsing surce a
#
#
# iter :46000, loss:9.928116
# woe pirst eru sere hfrace
# O' prem fomd.
#
# Firsculd or,
# Sake
# shes. sen hem the rulls.
#
# VILCENIUS:
# I cerer'ss el if to kar so cough, whan thich your rasterch sf haves nourureven
# Yough not brot.
# Norve bow
#
#
# iter :46500, loss:10.107927
# isn, muoe firs, us afint stases sunth cenoust
# Se he with
# wis I lercantenteld it;
# Hie for spocours, ffithell.
# If whan thon tuthy, sent-s; es you they farin douk? sence mamour if ste maus,
# I so being, a
#
#
# iter :47000, loss:10.012523
# scirscer a gore prake them you the ande
# suat arn Myely in that alves'd for spadsy; Oule ufow their avetenwre lesmurd kats is mamesele palut laury he serters wore hall the id',
# The tireed or, rved re m
#
#
# iter :47500, loss:9.941699
# er,
# What whisptar
# Aves ot on fiacd;
# Whit! -oth he cors my opeswe cor grof or.
# I fald iodper shoot I
# I, Wead wal it vithebnee;.
#
# Firds aml llong thith malceris.
#
# Be Got'R the: poreclagir ave fiand olik
#
#
# iter :48000, loss:9.784328
# rude,
# Shar vecipre shice cinow:
#
# First Cing, as salle, vall wnod'd; mund frof, mne.
#
# Firsy ouy.
# Whe hid they mae a ip't, coustie-conrtiWh shoy theveve im madimafers-g
# Awel inkert is yoor
# vond fro nmm
#
#
# iter :48500, loss:9.771331
# y wis to thes and,
# I Anaks,
# Fards.
#
# ALERGINIU:
# Whemels: igue, oles.
#
# A:
# The pece the gotry
# gors ive Mith
# Alf suplurus hant w'mwe
# Our arcith;'T
# Matizenseng-tid
# IA: on frey 'for:
# Thang them ting!o
# Whenl
#
#
# iter :49000, loss:9.785867
# ap es reetinde: mt stalked peilyfns. Seantin,
# Indew or is he itis butid; fortef to cenpevulyer. the hang veartousk seve shathun hients and the asmoong
# The rotod:
# To to romy
# Youd theircmand
# Aw, fercor.
#
#
# iter :49500, loss:9.791532
#  nit, and dak ow snouod thelyu.
#
# MOBUUUS:
# The powcyoof, lomes.' wid, 'sove dond uf oufrepen sanath, sobe wo cutl-t foll youle mo prive vee; I youd born neber'on:
# Of and
# s; ale doof hime dee shim man s
#
#
# iter :50000, loss:10.009376
# t, I slow besterstitits her: wict at nowen dithsizese've wis bro thmy; a mowm,
# Them it whvind cuk, oe had podirir cefterlatess
# rund he ittorecufits males, you heid'n them ke lit foode wous noure'seran
#
#
# iter :50500, loss:10.019031
# l wikinessesd you dey sore they the harm hed heags fled rakedee ayot; on.
#
# Thark so pimh: fotr: they uver a ther in,, thes co iusmand dayd.
#
# Secid lorto
# I thath, wance he for fras wood mnened they ou
#
#
# iter :51000, loss:9.847719
# n tyourk
# Of the the cood coull noteld
# Cakf fill twen.
#
# L:
# ENENENIUS:
# he
# Nouur, ruthI at lave beis to gort and the bar'y'ly wesall: gou firt, il aletou
#
# FIrRIUS:
# Rounderd
# IFer nothe.
#
# Fimy yous, on era
#
#
# iter :51500, loss:9.719167
# ravee. n tishlyos hel?
# Yit me! s arse sperith the comong yis neare hall I wair epet corcus you metide.
#
# MENENIUS:
# VNENI I
# Firrss sus holl doth me
# Cood you.
#
# VIRGIUS:
# Fou thins thast, that comy fid  se
#
#
# iter :52000, loss:9.648242
# igise feronert, tore butius, no thy I wis to waughy woke tave andoobly well than of thishan:
# stran shatus.
#
# MENENUS:
# Thet wo meve coyse daldiy mens core wither.
#
# MARCIUS:
# No seipre wieshith arel,
# The
#
#
# iter :52500, loss:9.706558
# t tair'd,
# That hen hilecitnes beake oo yes borsoensin;
# Whuat, ovellrcis ine ipreacnghesunt urs to gromys a' tellyous futss'mor pe toul: you
# Hove ist o' kagpoon; and lieatizins, to susd rit buther qrer
#
#
# iter :53000, loss:9.669728
# Ousfodlcin's mgicthenomiad we rang, upfact 'to are, hum rad ot- that one
# downiterl arterenaghirsCest erenes
# Ire:
# Oone.
# ith Vesucunit induf, wuted beon temrece, thene in. and ghans yop!
#
# First Cutbirt
#
#
# iter :53500, loss:9.880000
# ris?
#
# MARCIUS:
# Af one thee.
# We co, hooga!;
# You tolver itniniried a pelerort:
#
# VoLUM:
# A: Mot?
#
# SaLet Seares debonk attis, spood tortoftus tot. youn
# Ten puth. wough hilt pathre-lsof. The pook hithsplive
#
#
# iter :54000, loss:9.855297
# nst.
# Wit. apot ale matize; mwaver:
# To theigh, wiold to vendios shen: ving he hansbrece chusth: Cikizus.
#
# Pichthes; Lilk? Herer ie withry sty ar ins anst; whand you anour s; in hate to tham
# noned thani
#
#
# iter :54500, loss:9.733913
# ne
# Whece's Rou ture
#
# LlEUTIUS:
# That tiak, walinell we
# Whale
# Ainco,'d
# Thveved re't It, ther! Cate moresus det the veeiply end you''d
# wurit an the goors?
#
# MENENIUS:
# Thou whech ak y
# mavealt mnow
# Welly an
#
#
# iter :55000, loss:9.647455
#  amlobe.
#
# Firsus, anidsunswcyeed or erse rate;, a's, ands, gire.
# 't. 'r'g bale wes crust thand surd but: oulser:
# Yousgeinappre fhay,
# I
# And
# Cald
# boke',
# Your han mart woll: you swany
# The choich, whouker
#
#
# iter :55500, loss:9.530878
#  thes ard cares toml ghusice, whuaus! To becure freres mendeldesedost
# Arl seothe.
# Ti,
# Rodn bess wo ropit, muctinh,
# Thes you Hvear than tomp the kir aste pasty:
# It ass sore !' nof turm thens thom greve
#
#
# iter :56000, loss:9.638249
# he harsen.
#
# Firds,
# Sece forand ay.'
# Ih stor wather ater to kit, pirctis; man hiclin oun ker on couls.
# 'The rand
# Le thover: mufinesd nfis chats Hadis
# 't, neal hos wavene sive chour on--CI Rhe son them
#
#
# iter :56500, loss:9.576207
# ape cinst andite brsung.
#
# BRRIUS:
# I the low touly, I beod pother then on to me comd; re pomen becry trelime with his nas wecors I lone, the Faeprerit to Thus hey Vake me nomwelw condwer afe now ecubon
#
#
# iter :57000, loss:9.772165
# IINIUS:
# I thave--Ande and your wealon, dald acle abenood:
# Ooof'st thom hay thay, sist
# eakely wame abevoy how:
# Con I the Catr Levem afcuf ous oloure frough senoon hat of lowat you hod sace atper he ey
#
#
# iter :57500, loss:9.859867
# y
# You has muldsse wheolinend chellyizes sarcs, weis fatizen: senecoay wetr motosred oldy sorkest modis act o'd bealler', soree to ace.
# We ploth intedst Marter'dis me is rotis apst a
# danve, brounbtit.
#
#
#
# iter :58000, loss:9.791640
# pot as;
# Aed'tory the htlor theins, toe tandighe; yaer, bealy,e,
# Iflem.
# Butizen:
# Marsilvee theincerss
# couleosd neere, If thed selltizenctinit turubtirs o, the helamy me, tounssain, be turumalve?
#
# VALVI
#
#
# iter :58500, loss:9.872540
# e qhas rece reearinest you upow maredss beip, you ar git Roud nott, leloug;
# Whoughikests, sfeats the are no be plew diciuiu
# sterates the artores,
# reale that,
# I'sed to Aft.
#
# MENENIUS:
# The gho gor a kid
#
#
# iter :59000, loss:9.629775
# s'rs dethes. Whe leag angsty tfeam tall ome in,
# Bfen, thalshyo 'nit faibped dedarcr
# Leakeidss I cors to br
# wale
# And wo decewie
# Saled tur the bute theterster mesect yat tferen'd y.
# Ungotr llolt our our
#
#
# iter :59500, loss:9.805489
# es tall oe pies; Serond I ma'cgs toel balk onr nenme's haius?
# fors on Trlow of poror they as it, an his fith wult
# And y'ns art hes.
#
# MARMNIUS:
# Farmaf that heady weimven: you buserd we gare oo th, I w
#
#
# iter :60000, loss:9.793330
# on hes pbighe show thbitiled to cor cepong a drere,
# Sheelf leath.
# We baly higher, amepwingse co fenn
# And beragttin,,
# Thiit lebatend hemad as date,
# Ar
#  to lonand lork strell the porsers be wimnus inst
#
#
# iter :60500, loss:9.887869
# -d endous on thame wow bestre but your.
#
# VALERIUS:
# Cond well ancer homv of id a fors nauty hill ara delitlsst Camad Aubo on cor loth rall Mork mors hily beas the tim ghomith braod.
#
# Then who heand par
#
#
# iter :61000, loss:10.077286
# end wave disco dear ageserll conj
# fopeche ifden and Io
# Beplend to fitity of !s of you the butonr the lay
# What,
# Alded is thes you this, dell, wauking he gaowed nou toll bligot Cissich hes feartived
# Cat
#
#
# iter :61500, loss:9.844157
# ef leso hesall plotre y all ne'd; ave in rome that reathy, Eou tall erad o'cl opes?
#
# Sarsy veave didsing paber?
#
# MENENIUS:
# Nealdtent sale se beagike!
#
# AlElIwINIA:
# Noth welllinest hars? tim lam it blll
#
#
# iter :62000, loss:9.757153
# r soll
# thithad, to bore, you thoo has hay.
#
# Fit toml drery tar comous,
# Ofs!: dfeat, the Voor, yituth mabtioe
# Ausnont you thise velaiendine cemig loof prece ot t', inicuur ard
# Thesent intest cristrepro
#
#
# iter :62500, loss:9.475495
# t reveds it my theind
# Whant ding they, that notb:
# Wore spectte hit.
#
# First Cath epong walv rs oMat th af the ulicrusm detbenres,
# Womead.
# Ans I At the ray.
#
# VALERIW:
# ID hatis my wend thike malfsinut on
#
#
# iter :63000, loss:9.567043
# ys detrtelf sorate hive ses sucis I Aused Margs or ou.
# That frid hive wa hall not fob kpour precs re im,
# Eod up, datesd fingres.
#
# SOLercutour thel
# with
# Ou a finder dive?
#
# First Cakes
# And gastore pre t
#
#
# iter :63500, loss:9.508173
# :
# You heas?
#
# MARCOUS:
# Habed datlel tandtely ef reay, IveU,
# As'd dadtius. Mooon the dage s ald the lestercs; vallinsin momve it ery, ink to had toer ses acred, whans that andly hem surs moDe yourlors.
#
#
#
# iter :64000, loss:9.520174
# t our musd thatis khon gorserven
# you?
#
# VIRUMA:
# Ant shat hepse't
# Ancone Sil; in on
# Alabius fos marimers, food
#  maathend he stoth, hamsand in bend areninito a doon that to make frece are your rumwy, to
#
#
# iter :64500, loss:9.748203
# fly wir mond Cous ale ta cougsin's hee strom m'
# Fies sall of you water his; whenge, in; and us;'Us theed em powry, Toll nad bt the compr spoust bemiuscisdsis not shan five ufcorer,
# Hang onow's lupfarg
#
#
# iter :65000, loss:9.719986
#  you. ho mo'vew
# tort Ciliu tay huucus; Mornk padt set han covene. Beretand,
#
# Ye'RT' pfome s'st yow ruct, Marche took er ally the moong say alt he assnert yoo dow'l ascake. I thanghies comlvew dow then
#
#
# iter :65500, loss:9.708141
#  goor memwod in whiust'dsels blim to pay you.
#
# MENENI IUS:
# I'lipeean
# To
#
# bet.
#
# MENENIUS:
# Naity ywe domsusm
# bese doy't
# Your milded the pow comou youlv mik wilkerwus blourus'd
# Tall whoussy thiat on-
# Wo
#
#
# iter :66000, loss:9.543478
# lios w
# bake on ave malmedsecerse leatet:
# The pake shay-
#
# MENENIUS:
# MallA:
# First tirctiusiwis adems
# Wo, made sanis o the boliuseswall andsusen urt's.
# What you dark ive kir'stser thlest
# Your he selly yo
#
#
# iter :66500, loss:9.594819
# tore tive qued
# Wo in, ow make
# Whomeicn copes walm wanst sheerer.
#
# FEr: He wefivusteth oulooe, I mrips; deaties hinkere wald
# The cous mnminkot poon the his eoth deitt:
# Themly
# Btsubu:
# The bopr! And the
#
#
# iter :67000, loss:9.576736
# your.
#
# MARhUMA:
# He sasaming thivy an whir garous artiulertorem my with mipein ciust se?
#
# MENENIUS:
# Set be,
# UMAnsiN:
# Nhicp I pleplong plutinen:
# Beat,
# forcie upface qobes, toing frich, we lus thene, he!
#
#
# iter :67500, loss:9.641637
# k his by a'did his dour, our warestrpither fate forthith is dyow girsce Vyot mave-ffof is''y
# ould wiss!
#  dimier!
# Thes hetnt im,
# That hicour maalile, thus!
# Wheme
# fourt in re's.
#
# VIRGILIA:
# What an fron
#
#
# iter :68000, loss:9.883051
# itermes:
# Thoushisend farhhen mumyo
# Lell mastlines!
# That mimers, furier is pake fyod I chow the knonI, foory,. Ho peviwe-st recond mencurs?
#
# VANENIUS:
# Wtreak gomea
# depon; he preake bake liverst comm te
#
#
# iter :68500, loss:9.808831
#
# To mamarmpiry, sor? Himecome.
# Well yous?
#
# First Cit Carn me us lourd our the lore that are sate fore hims ackinen tyon scarny thich luts ere'
# Wane that hamf ifdtorgale.
#
# Seats
# es cortined you utsinen
#
#
# iter :69000, loss:9.666162
# omebss feipve. I! An senaverry
# Austy
# gort if alpy frele's: to Mactitizencow hisssuf.
#
# MENENIUS:
# Hellf do re gaten, youmirvoar in hatizen:
# At an hive whit-ned becione,
# Thee he shern son'd,. ghou'lic! w
#
#
# iter :69500, loss:9.511026
# s, your foispens--t
# Marchey.
#
# VOLGMEMENININIA:
# Wh chath then
# Youn't axm wiges caprus
# maten:
# Whel.
# An: reve the be ave in fis hes it not I stood fate the fipcnsus your, 'tuts; mull and,
# Leterds beirs W
#
#
# iter :70000, loss:9.374954
# ans are.
#
# MENENIUS:
# No Onangh that sus dibg.
# Narlige at at?
#
# WizP;;:
#  he boutizes's, welak, tringher Lithisest Thuse high ont in
# D-Ast loon wexm it you hes 'te.'
# This, one thet reves'dout beppolly;
# 'f
#
#
# iter :70500, loss:9.470106
# 't, it Meple farpuiur cominent's the boob,
# Whirs your ise
# empooge to thef that bore,
# Ans I dormone the gatien;
# The lenow
# CFitscomo?
#
# Firss that fir mofen:
# ENan
# The menswoe wut to reitizen:
# Me'st be fo
#
#
# iter :71000, loss:9.391189
# s his ouferiom it for
# Iw, I ho gor,
# Cors.
# The nond have sstend comen:
# Lelly wand Jus hamp hich mate no
# The reswell.
#
# VIRGILIA:
# Sarus your gran to mar aladiricies that you oull, now is ars by wiR
# your
#
#
# iter :71500, loss:9.631088
# ecte wut to geme, in to avel frat ard heaver on in them as to fably;
# Seak, thous. Her chas ef yourelver.
#
# Sedise alllys hay ar fore:
# This bleale
# dace wheer
# Ald hat ageid, dougher and is;
# The goell wit
#
#
# iter :72000, loss:9.664001
# st andt anfomest the thaes, with wive pores? buster. find I not foart.
#
# MIRGIFIUT:
# Andendires ane
# Fablard: that,?
#
# First Caockner tort
# , I mlosicyohens, blruds.
#
# Secit momands,
# Tor and enmoy, be in ar
#
#
# iter :72500, loss:9.551036
# hert on this pros out malcuns couris sat, a netore
# Spremowimo,
# What'd not Cir:
# Wicitt sho is the come
# The grene fomy wirned goocha grin this tpive fit then?
#
# MENENIUS:
# Nare no medlle-ghere?
#
# Lell: but
#
#
# iter :73000, loss:9.474393
# t geer
# gremust yerif.,
# Seave coiledlye
# Toe grustr grang; buts wordy to thiehs do be'd
# Trear, toll apangrithor,
#
# VARCIDIUS:
# Copre, madich; I fiest wilte-t; unt mvirt berewhyo I ceuster?- To thoughur
# FJ
#
#
# iter :73500, loss:9.475775
# is that as ony'dous one,
# What then heat in thet ernus too ericce anl rbean whal, I onw put ar
# To' in hued you
# I Eres a reme in o,
# Home berie sale weed corson womave dow nelonesces's tos asd gay tavel
#
#
#
# iter :74000, loss:9.498528
# oof the call, shor Hest his
# Rore no eror mas of usse-dige lalius,
# I's:
# With itofrsit howe,
# 'th change the pos I whistlly best hong to Shispon ly y
# vimesucou to liags ort Auke heak,
# Hesterles, paacs wo
#
#
# iter :74500, loss:9.468088
#  daies aClin, lake your hom-swon't enie has?
#
# FArsw
# reem re onvend, hail if nour comk non to bethen franse I houg beprirse dower it oo the danse s'rcint:. Vourvuns your fa the ot endes! the thang the
#
#
# iter :75000, loss:9.661022
# hes
# Ance warche to to tis le reath
# endis'd comlipiss ur!, wie tretort to tues harks, Aus cotiest
# Butoub!y, she for dobwoof tenoor and tither goom chien if lit hium, gair firthe: thisur, to
# itiers, are
#
#
# iter :75500, loss:9.707861
# est to wyoe to in; not you you leis mores brundy it mators, peviuhinelity the reninds
# Of as inedoo, cone; your rsingted an the reladsussstent cry-gas yours?
#
# First Ay as undoofy
# But'lT him.
#
# First Cil
#
#
# iter :76000, loss:9.483621
# est sticingo meed yier comlines I
# soo
# The leak mucpun to that I she met, oon.
#
# VIRENIUS:
# Tingsway bome in the aminded theys maver br nga thoushay, In coure.
#
# Firsthe what he rood's, I
# sild weulp you
#
#
# iter :76500, loss:9.497040
#  brow sevesrelw murbre.
#
# MENENIUS:
# Lobl thell griod thes ill eabras, you the dell,
# Ourcus ke as Rom seape anbt gous, veary me,
# Ot, hit; the realuad tfortor,
# Andidise as offirce hy andy ave
#
# Olpflolt:
#
#
# iter :77000, loss:9.213343
# 't.
# Hall, ame har ond, the coblionnced Cilvodion; in the giptif.
# You that hith is mutizeng
# Coll,
# Forsmasbre ave them on baven:
# Whouk; nhear ator? the verp'd qrom, note all,
# You matily
# Wo, this san pio
#
#
# iter :77500, loss:9.371476
#  and I' no blow indisenafe.-
# What youlyou shat butinen hed oner he
# fitse this cand in morg Call wan
# Senaed the con cor sensweriusuas,olat:
# TVacgay so ma nans.
#
# MENENIUS:
# Oom peal ensur
# You
# Weler and o
#
#
# iter :78000, loss:9.326889
#  you the honest and
# A'st tho buve boelady.
#
# First Citizen: venee have of in mbow the frou
# wirse th ngeat dut I mfot;
# Le surdarcil, I pint moll bery they on that aned in bods her my prod it, it thigh a
#
#
# iter :78500, loss:9.423311
# are comeths,
# Howf; ther is what houghad he itiags the sweis bodied hall
# Ladakte- fremudin; your frouutow blomend ave there hive bednes'd
# Opend he hais ased, dee bele he whened: porsid haked:
# Tur.
#
# VAL
#
#
# iter :79000, loss:9.623985
# eed
# rre pram the cours! py, to that we alinent, The catehe in it nourte, Rov mo feokeith be not are to hice corn fotthes.
#
# Firss Citin, I hoth pungowen to cition,
# Cive wanchor not atinous on Rofemay,
#
#
# iter :79500, loss:9.450248
#
#
# Ander
# Hoved he canils acdicatiugs, that ngoup?
#
# VALEMENEENGkhen for t beals py ickm ect and you Sabere steim the Velfinas thim all
# Oultous
# Hod
# Cang first Cotly sipl or ast wirs. foppitizen: hith pre
#
#
# iter :80000, loss:9.524558
# an hate arowe mune,
# I'd, Oto fits and melary,
# Butne to lit that hisild
# Aw the reatides, ans, that you af's thet. os a ming abage toee the wome, tr mad pardenk tome is
#
# VOLIIA: it seaes;
# Saneflowe rak,
#
#
# iter :80500, loss:9.308981
# sich
# Dend you
# Whel mlodrse Harterd: I
# de's vord goofmorating missell.
#
# MENENIUS:
# Therean in o' hong ave and girte'ts, The not ounsedstous sere is brocer rust entoll on gire, deritr chome
# Wize that, er
#
#
# iter :81000, loss:9.405884
# s,
# Salins I chellry be wishe the cord be a peaked foom?-
# Wh mir,
# Wane flit me resellle the thon at you lowend cor:
# That Rond aclatben:
# IN fare, and,
# The mitil-,
# Wherecus;
# You he inest in then?
#
# MENMMM
#
#
# iter :81500, loss:9.404678
# hat who resore Shen teeve our spred vedond it not well ared thet him recore celv
# Comly taand Con try!
# And wau wimns at a non to thas marbun thas srith!
# The cipr stor,
#
# MNENIUS:
# Ound proud
# Rower illyof
#
#
# iter :82000, loss:9.436217
# aprab ty mvere alcide sirse filj'nge, hy gos the spotsing'ter.
#
# VALERIA:
# Nomest:
# As monout westrven vind ineeldercon? thes first elhere'ts,
# Five waremith corshipe fou
# Than henre dis be,
#
# VinNIUS:
# The
#
#
# iter :82500, loss:9.622371
# age you hit 'ome ape that her tiod his meeitizen:
# Sind ius.
#
# Sucping the reat for the brow
# I I ceas in.
#  beaths a notter and
# was?
#
# First
# Sece you and cus but
# Be corstow.
# bese lalkersar on facands if
#
#
# iter :83000, loss:9.469687
# e snot ame and as cose dedatoll the hairusly tuat, I'd't'lp tad net your could uclle?
#
# First CithCe is.
#
# Firy
#
# Senyat demiunger, are
# Cotjer to make faondss ence stoy the insurs aid.
# Weprids sald you t
#
#
# iter :83500, loss:9.441070
# nt Rond you the cobmondius wo'd tuest sho cits,
# bing'th my he nour mious lyil maveler oull. Whor of proow
# Sing
# And;
# Eome his are muvere the paken mave shat in; the gitis coule and
# Then
# Who foul we aiv
#
#
# iter :84000, loss:9.247824
# g hees, your ray, Citshithe ming that fiesed stere--of the pa reang to yous, what a lat, and ond in wase vasuve ta'ldtous seard mighakeed:
# Erelly; you to wive cane that our fint, seay, fon thies.
# Whe?
#
#
# iter :84500, loss:9.260246
# :
#
# MARCIUS:
# Firthrs,
# Falqulds. Tue porly. Mauck eilow,
# And nathelis they I's hore histaf they landis rattI afffirant ilatel-, that inseifourss.
#
# SlcoUt: What'd:, ben with pevoncntU The kigebone smaks
#
#
# iter :85000, loss:9.178658
# orel 'vere partryn: no for my mnest geld heves mevest
# Cit:
# Hore, prough dowo'
# ked cumblvius;
# The eferesf't sutreae
# Foort tothe
# Oly--o in
# All erot'd of toanune,
# Btor they wus!
# Thay
# Shate anestite cries
#
#
# iter :85500, loss:9.215564
# iund comety my the fpolend reit,'d froth reser a miy.
# And sefpill ard themest andt heed ine
# The bubligh gomes.
#
# Fius chesmow
# BOfe you lowiuss in what ware, in ipen had of bly you hougith.
#
# Fir,
# Sorn b
#
#
# iter :86000, loss:9.490888
# s, I dad I gaily's of cet hes, dis groy tutred cemafius, by aod
# boliusungely tay
# Here; sben f.on now's he ar to't, whemes.
#
# VIRGILUS:
# I tre thard man to. heve
# scat in then h o' sut to hae pale butizer
#
#
# iter :86500, loss:9.406518
# ipon:
# When usgeartioneds a haigh, it laacter, you sigal'd!
#
# First Cillors sales me the his? ast larese ta mlousinge. sCink all! Telle sudilr olafinis coll: here havear inkther 'fear ble reabusis;
# Youk
#
#
# iter :87000, loss:9.410377
# irs.
# e thith ur, of his pranst
# Sowis
# Senucled it mo kell-l-ang anl by arces.
#
# First zen mellakny
#
# BRGINIUS:
# Be my netoug'd,
# Wevag mlly lalgante, his andsen the grill nlawitithme,
# Benate in turt pood C
#
#
# iter :87500, loss:9.311695
# ve'd thang
# ure
# prim gond my heactse vert akledss of Ratl.
#
# Ad paratets, Iver fase our you in 'y! four. 'hit.
#
# MERENIUS:
# The roog hom; a raak it sutinount. Wheillirsifoy the hong onow,
# That ersd thaml
#
#
# iter :88000, loss:9.273477
# mpoustore
# Oels youn?
#
# First Citn is if and in ta re Cave notr;
# That hatly sat the heiuth to, tull wile.
#
# MFinkn:
# Weluriginier, Ane Withe. Weak?
#
# Firstizen:
# Their to the sunfer ame the beprowes Jut Ray
#
#
# iter :88500, loss:9.309049
# ippat farous On.
#
# IUM:
# Aad all whored his good To is pownine, they gorar, ceimica onen tlot his sat they out to lak; wilth in
# Rond this at un,
#
# ery'
# Thet amed bencs in
# I to pood deale wattnove with ir
#
#
# iter :89000, loss:9.294209
# d not he han in one,,
# Missenl horl't loof amall come?
#
# CinGINIUS:
# Gakurobl miffit ne fold hithe: shirtik:
# To pstiths martor.
#
# First Cithe here; a loud ware lile woth romady, oud alile sesen woum!
#
# MAR
#
#
# iter :89500, loss:9.536441
# aloplood the buter, softing in dime, I'd:
#
# Aver: you ourbloue andred reod that ardwed well herinst.
# IFheend stea'd, one hetel.
#
# MARCILIAId feat?
#
# VALENIUS:
# IT's Bderiur
# mofeldence.
# Whe kenee, to, was
#
#
# iter :90000, loss:9.552573
# uch; fiot mawes?
#
# First tedy,
# And therere kaleed cellr ciuss
# If they
#
# Ald: Tou lowhers!
#
# VOLUWIS:
#
# VOLUMNILOMd, what hoy beend is a'd hemors cith incarst roid tay sut ivide,
# Bepocesinis;
# Of bre tomes,
#
#
# iter :90500, loss:9.310887
# s you are a wence,
# Wheill renoe, 'anly toy halk be, you mally wiukiy
# I oped a vene-dserted ald he mitess,
# Thetr:
# What: whatur omatert have--Avealimeld thh sheblos the chave a's the geeit, fom, I
# , att
#
#
# iter :91000, loss:9.223943
# , selaofr cores neiug.
#
# MENENIUS:
# Weichinow fir ureads weald comly,
# That
# sundsy't not is a matore thet and the carun ins
# Devet pardsen shounse ty ther hemit wele shi y tbrucist sich he cith, ar and ul
#
#
# iter :91500, loss:9.127222
# ome I thel srade-d oll taregilgect have pirst he s akligs?
# The gaibs to kevet
# Whuck.
#
# MENENIUS:
# Lutshoud he cisth bail, way, do arcesty; stimt, The hef
# cons the put dor his. Seay's lisk for hount
# Cave
#
#
# iter :92000, loss:9.198832
# t zear, the etrre cpobs, Alve cring the recomrs is upooon's roped chour did a cours, A butr seat on:
# They?
# Whit, selin piof--s deters and of this seam at iurser mensiAn nour in harksed it,
# Oo, luditow
#
#
# iter :92500, loss:9.113760
#  and he grones. I
# l', dad onf shef of they ind to the haus face.
# 'V
# MElENIUS:
# Whee a
# nobe they senade illay satt hal,
# I in mling wamh at'ts foly hes yours heed pre fich us wale prow
# Were lanours it th
#
#
# iter :93000, loss:9.343977
# o
# hoon?
#
# SIU:
# Harukes hoof'tour that are up deserto we'luth, you dil iftell'd. Ageces and-s I ald thoughther: a nortelf youread on'd nopeedsn thime. 't ladarinssoland looknouk.
#
# VOLUMNSILUM:
# INIUS:
# He
#
#
# iter :93500, loss:9.375111
# gstith he growos. Hem of your shoung
# rengend the han fomy in notR. Hesat it.
#
# All:
# Co his and the kan,
# not you and of the beay my stichs, and elan go share frenth walurd you,
# Undihsun? ctich lear, tho
#
#
# iter :94000, loss:9.238072
# on the pooraste thouldeven dest
# Whemedters aisd or age
# A pre, instit.
#
# Firus,
# You meerius pitt, to thobl hy
#
# Lecond erovinen coulds is welitizen:
# Hedinstoa wheters'd to I they have the finst you to th
#
#
# iter :94500, loss:9.254854
#  you spaichs at eiselle ar a retizen:
# Ethiuskown:
# You.
#
# Fir's Ciry's the agaire-iS: in maninged t'r fitizen:
# What mond to noogh
# sprathyithy the blours,
# What.
#
# LUR:
# Hed come atly oo
# When hir counte hav
#
#
# iter :95000, loss:9.136368
# n mad they omer, Alvew thates of a mester, and renets you wild is whes it stbefet srrusting,
# 'm,
# Ous: gasinit mire coukne wene, wan:
#
# MARCIDIUS:
# Nanoull that nothes, Marn,
# Cigscalls heactus.
#
# VOLUzUS:
#
#
# iter :95500, loss:9.268295
# f.
#
# First Sftonch wor ally Tist Cayst migharili:
# O'l mof ununt,
# Fhisd il, and sirbkestold thas, onen the fpo mumes.
#
# MURUS:
# We leav the gast pribudirs:
# Thelll, forther.
# Whorcgorn
# I Of dittrut.
#
# SIA:
# B
#
#
# iter :96000, loss:9.187206
# g to seise sheall-:
# Their ham canch in Ro dave a lencey sooken, seoks, Aimcourinanse-cound on.
#
# First elthonns?
# Would wyot we vaother hemad the make whing a cearery, to kave he to shoud thanghelo, to
#
#
# iter :96500, loss:9.379819
# ead
# VOLILIUS:
# The wethesth dow akvest
# Werbenoof.
#
# VOLRRINIUS:
# Candion?
#
# BR:GI bre my the arseve hove bod you bue it Lar heeld the vere sheichad, aglursell and the pacce it a pgrom one thor goove wood
#
#
# iter :97000, loss:9.515135
# o that afe and in hing
# Cont I scat Goremusange hicy, and, the whate thougat, anden to the Lystoy, the city.'
# Theisgelily by
# Mither they in be the Choong a sweed.
#
# Apl:
# Nhey amfowed whom neditsut stree
#
#
# iter :97500, loss:9.226387
# iel. What he in munke;
# The that lood I gaabs aily abour bnemodly is Miren the kike see sellen; it nod dis yobe oult: if then,
# If a but menstor:
# I that rown?
#
# Alsece pitalf leave mase the wamly sen the
#
#
# iter :98000, loss:9.242749
#  apedse powme't Cisies and ttomm
# The reanits nat, they dean a mo to till we!
#
# VIRGIUS:
# No than
# gheth wele thit me tall ggay.
#
# MENENIUS:
# Whe remeake he arer undicts thak go, the ans,
# Und rive thime it
#
#
# iter :98500, loss:9.017434
# nces on be mition whain; as, coblaks to pall
# The none,
# Wing blik
# AM
# ALIUFIUS:
# Make cive hart, a raikes eirst it socut
# Rond wans me
# gelain tosmyig shat cheer.
#
# MENENIRIUS:
# Noon seend if. ghe gros thich
#
#
# iter :99000, loss:9.159556
# USUS:
# The sw leonce.
# Bemin; thou the prich one I migh?
#
# First Cis hir bednon-h
# We lidaus is ne'y bear'd
# Domve.
#
# BRCTIUS:
# No in't-Se
# suranest floemorvidiur depre anst viethy, Sele, lake.
# Whith: ust Ci
#
#
# iter :99500, loss:9.117683
# r but, ho me decike that The bind. That we nenere horter!
#
# First Citief if thes ame call wor wou us haker hucrys wous warst could you--
# sud momenverf be weingoon nond
# Wowiucser ilf dill, bres, weeas.
#
#
#
# iter :100000, loss:9.130530
# --
# Ankow I spoce hathus.
#
# VILUFIDINITIUS:
# Malchin shat 'ed you a prersids or ay when,
# O! Tiven lean wescomy, what bercailaust
# Comp the bond in count-.
# O' nepoly mrow waled thie patid. gove acnerad, no
#
#
# iter :100500, loss:9.366078
# I nope paf!
#
# All:
# VILUMUS:
# That hich in soat cs, stoa the sten,
# Welcetiran's did ervery, your when withedis with ous arkiub,, Ro thon brow
# Con-Bgay then wiken neltell!
#
# MARGIUS:
# Seand. Whoofh to the m
#
#
# iter :101000, loss:9.210743
# ne of your my himed
# coresus
# bect.'
# Then not.
#
# hacey.
# Whuters ar buticiust nf avestis alm'st fitne ;
# in.
#
# MENEUS:
# Nuead ur the onve, the wam s'rpnis outens.
#
# VIRGILIAR:
# Nituls, not atong the proselly s
#
#
# iter :101500, loss:9.326399
# e
# fhis
# Tot hor bokes. Whemes, day andy, thather,
# Alitis:
# I forems
# Is the beet,
#
# Hoscy, metby
#
# First Citizen:
# Yen masharoninh, upun your of theichy' do?-
#
# CIRITUS:
# Of agity
# Whend des?'
# ghately el'd the
#
#
# iter :102000, loss:9.054591
# e theighacesturself thry des and
# Leds mantend upeags that sirsty't on a
#
# Fig.
# He sene.
# Whou dis that preious wank to thel 'voudy welgouth shioy watauchet yourm
# surses.
#
# I I thor shist lay mlow there s
#
#
# iter :102500, loss:9.159630
# 'd,,
# Thour tome but to healinest rad ene ace the brom pucius as do' he speaker,
# Morst Camant our sbroo, sereserss.
#
# First Cill
# Aus the Vore hes yous.
#
# SI IN aghed for is gomatory sirs
# ettrne---Bere.
#
#
#
#
# iter :103000, loss:9.074504
# r:
# We carcesmone to
# 'tour this freat a fent blouriuius hemolf than waus
# Fast Beis bove by'es, he thon: I
# I jimirser of setingun,
# If
# fordionhiust ons'd ford nofke warl Faist:
# O
# Thert fit snowe pree o!
#
#
#
# iter :103500, loss:9.180170
# ; and hatius An hos: I
# bode, ave anes he
# Goot'd selle: doos. Thos nouniff.
#
# ...
# on; and of dave his tour sward with mannenwuat this gomt corniff they. bnead. Be chith ven the brovours,
# A vembing
# Ay. Frothly of bopl at that I ray,
# That land
# dock; I ngevith, in rems frunged that a,
#
#
# iter :1221000, loss:8.507972
# triciad,
# As than his refeamith you-.
#
# VALERIAsGI day toe polry like is grosthe with this fread Cairsund, hang have
# sto deangs in our tome
# Hay a proch, they you
# O'tler us;
# it, and cat heveitly your had
#
#
# iter :1221500, loss:8.721119
# his fay this More hir wick for you but to an mis theich there as send wor body,
# Erdan; I what I lacty, I their
# can cin more hade for the corner this bure.
#
# MENENIUS:
# Beff theinoun mosto you, preaius T
#
#
# iter :1222000, loss:8.504819
# the putture madatutor carneres heangain.
# 'Then gard, thus acterm!
#
# VALERIAO's I shaln us foled greathell. I say hionstail'dy 'ak ap enes sall it anmar urs ofve coundugh a bread first his fand Citither
#
#
# iter :1222500, loss:8.612765
# one in yoully?
# As cance muplit kndee it to thom wisime firs veelion;
# That the wholeve miot our mone ih hing the owanss,
# To the ciacce: thallyean hore; so nowly
# A'l and muter theings,
# The bleplice'l an
#
#
# iter :1223000, loss:8.389894
# ey you lave,
# And agair, has deow mode.
#
# First Cilt,
# They cratoly agairsly, thutl-on the plood: uver's Juth thang of slovinde;
# Lad us, I they lagrs, Bathl
# Theng a not themos of dut hime recery yoo pirl
#
#
# iter :1223500, loss:8.509159
# rece feark bet you are onousedend sorveme to tuff'dy werke Hid wibldseds at corastolys are to that, it live shat
# butter:
# What freived;
# is thing belsy hing they.
#
# Sarust to myeare garour; it then ur, t
#
#
# iter :1224000, loss:8.371433
# ll thear coun a bres! Secall then ance he quscours folds; pat to cim: fith were-heachy I mere,
# And guve, we lape the plricinius,
# Spot to dive it to prefortent
# Sensing Rome verniter strucius, if I whou
#
#
# iter :1224500, loss:8.431562
#
# Mell anscons tow unt truninger rems O''d hards?
#
# All:
# Bucksed that arn hiagwawn a lof'ty
# Wenh on.
#
# MENENIUS:
# O, then they it.
#
# VOLUMTICINIUS:
# Hes I landow.
#
# VALIAIMe: I have in,
# I seis criciscon we w
#
#
# iter :1225000, loss:8.642809
# ke herpof to kleft: our on which have is no gittius then are, appathtal.
# Thear the hare--
# neck recointher faze fore consing't our diturs ifland palfe word, wheremoors as 'Ter vunts!
#
# First Citner, anc
#
#
# iter :1225500, loss:8.467933
#  one yes. wave it,
# haR:
# Is gronse.
#
# Se: I meeplitore stick Carm'd I shalam, I sare himbry iplace nowe hay gays blry wees, not prow
# We robgale
# If daidiat:
# Thou hipilike at from,
# we! am in hing hemed on
#
#
# iter :1226000, loss:8.518957
#  well heatile suf, whiteste sirfeal'd al cich for hell tee'l
# Ard hemined! Tren we comour.
#
# First Citizem this noure.
#
# A?
#
# MENENIUS:
# Have see anst's makilither,
# Your pra'tolds to thesell, our pilf male
#
#
# iter :1226500, loss:8.413463
# seell that are the prow thife llous we count tore carous shall hing, and or bnder.
# Has toung an the mrough, that brelier. Aufist.
# Whichuly, le's,
# Whow Whevink you. Well ie
# rof seevicien to busine't ha
#
#
# iter :1227000, loss:8.428254
#  in are sporelelalderch onouciuthelfery. kndeat.
# This pram the swrang
# surilies and
# Martur--grat on hebe they, that lave he to maen the fabul they
# Sangher
# ining Cairs, mis
# To brat coll proves
# Nou, whe
#
#
# iter :1227500, loss:8.345306
# will wauld again, shous.
# They sid,
# Tial it, fruives to than nough y. Won to, toe musither of leak, be lot the Lids have this of thir ho
# Who where him,
# Our lone to buntus yourwe lo ald the sincus, thes
#
#
# iter :1228000, loss:8.379092
# Fy? make he
# comes thour'd shon culing Varceiny, oveer it whang
# dimbooky toll.
#
# SICINIUS:
# Melin to answor:
# Beat once hang batly hushady. I wis for us Harnse first of as hithing?
#
# VOLUMNIA:
# Heow sofff a
#
#
# iter :1228500, loss:8.591702
#  shal'd. I shat,
# Themealally all has you
# Wore ke you
# Welaoo; ow, agbindelf you'l. This if goer and of your are than his sonebidige wims 'ater.
#
# VIRGILIA:
# A mancsenaus, Gor ort mast to gaubed teck it t
#
#
# iter :1229000, loss:8.571749
# ent you vieds, I klow What nong Mend Cids; whow ha
# doolinius!
# Tresunan in the bleply pray,
# They,
# And to than wer? his stried speanunurs.
# What tablow
# With your whoo
# Speecches! Forture
# Butres?
#  us: on c
#
#
# iter :1229500, loss:8.427746
# -cy,
# Your kelone,
# And beerce he the pairy, assure meery, your uss wall to sin actius, an and ficctelller peatter. With on that prar'se counbom, in havemserir boresplils,
# Ander youll haly ay you prems
#
#
# iter :1230000, loss:8.395721
# he first cellow way slow your proue is be a veid; and him Vorl, wherwets, a kine bleds anlter the was doow love, dive beat bun the lign-bunts,
# Your deally, in rithy
# We nefetGer madang. Here; yablow's
#
#
# iter :1230500, loss:8.358916
# o I it goog beats, good us swir it, belly to ture,
# That I affetwnir
# rubitter first on a,
# sid un this it.s
# And ougrare-surtud
# shrey toll onswhe
# You swere from sich affwn Marcius'd
# I leabust the lies en
#
#
# iter :1231000, loss:8.362367
# r crrus head't enot him in mulit elemy his do tas ablig us I ames mese for the was
# Levis cond o' the ciemplihius,
# The geisside, now: he pathore hone.
#
# Mevens to give statne have for mistwhe lad the ve
#
#
# iter :1231500, loss:8.298587
#  be wood hiem wounted. That.
#
# First Citizen:
# Coffel: woy bet of they I if,
# And them o' mienly the way you the stall bolly painst though all
# Underding, be, got foo, whees exmod.
#
# IsIUS:
# Iver he.s of th
#
#
# iter :1232000, loss:8.510550
# eling to than peices;
# Whathers: That crustwell artey's, carnes
# Sim, lover ars'd hie ampoAll were stortos
# sway. Yourid cuss firt to rabs aply; I hearewance;
# As we see themed
# Or meel
# it ifpike aid refpi
#
#
# iter :1232500, loss:8.445533
# l me for is
# And so hars here.
#
# Sicks I te'l and cargsoo
# And peattell.
#
# SIMINIUS:
# Fareers your caress the Vorther'd not? on.
#
# First Citizen:
# Whoth ho
# e feies more crave tor himar. states agfend out hun
#
#
# iter :1233000, loss:8.353760
# ?
# Whe can alier: and campet droun you.
#
# BRUTUS: Het lece will no, sinch, this LaRGILIA: outne,
# Of you hie gre me.
#
# MENENIUS:
# Bufies ere
# by, they, is Carisend baky all poveary.
# Bet you preem.
#
# BRUTUS:
#
#
#
# iter :1233500, loss:8.362955
# kt. What halr.
#
# VOLUMNIA:
# Btio'll himes o'th good's't:
# We arour
# Awnees; he, and, that am ont yaul. Yours, thise lack,
# That wo sev
# rocies one ciseling Vere dare for be.
#
# TITUS:
# Thou hay. Be is maicver
#
#
#
# iter :1234000, loss:8.271342
# o do
#
# MENENIUS:
# Nould
# For censure
# nadblis nowell me re's Marowilest theien severe war hake that Rome all raten.
#
# Bejean porel; would to yoould kly's onfelfry bat
# fit he are
# cut toerves. Whost?
#
# Secits
#
#
# iter :1234500, loss:8.378629
# end 'tmis they now 's!
#
# All;
# I'ltal?
#
# MENENIUS:
# For in the Citing one we his
# of dispet it.-
# Which, I that, say mepness the puen though a notly, more,
# Sece. For
# Winpupralier ab my; for in this more tha
#
#
# iter :1235000, loss:8.250643
# for thofh, but a mance. With ngert elower:
# What endout must our mencus; and him we the rearted;
# The Vol! boly, spear wicinat.
#
# SICINIUS:
# For mome.
#
# Second batr.
#
# Fyry?
#
# Ercenn hed to gite, spead cemse
#
#
# iter :1235500, loss:8.443900
# ry you how h me from our of barn giveives
# Undeats a los whech leeredy that west eber, lall
# And, these and porfe mistt'ss sons, the made he's ding heaor his depplis we more it:
# Thel the bron Themer.
#
# V
#
#
# iter :1236000, loss:8.551015
# hat
# 't sendelours! Fore gower heare what ald to did, he hid what
# buthce as,
# Thou how of actiell ageesier this wo snath elome; you don he-on's the cobswred no anow
# Whauste the lat kner and resormvat to
#
#
# iter :1236500, loss:8.306486
# more fith me ving theme fame. With the rave bowner hir in of the reatius, thirs that unsell
# All
# it;
# iht olfe bect his fit up
# Eikbik ved me, they I so knot't
# frate fir moor ublater us be in shrre
# cons,
#
#
# iter :1237000, loss:8.435656
# d not madich, ass, angers theyo 't leak yot us your us 't a count the lieds of Rome?
#
# MARCIUS:
# ISt, botter all sho dally the revet you him
# And of you
# A aive him she calpercearce pawnucbs, that that hi
#
#
# iter :1237500, loss:8.211694
# hour to thes a benys oth a parme?
#
# First Citizen:
# I will find unsus the res rerust frreclile then with ruseds, he Bue are forth it stindoon moda, you that that are not but, here mencon: I what do in,
#
#
# iter :1238000, loss:8.397594
# ,
# To thise mysh alded
# best thawou
# The godsend in the mretor: one ands, morely be ture the lorved wall firsh
# e thened
# Cont everm
# They--
# vet our boding here whereblly, is challds. I vincoth, stickmed yo
#
#
# iter :1238500, loss:8.261632
#  pere.
#
# VALERIA:
# He shouth ont with was a was you
# Some are spald it a lees, well you mall you,
# We hus despeate ald munt
# Come: rot, that: four yours of watr a mods I cigitned rembrines.
#
# VIRGILIA:
# Ast
#
#
# iter :1239000, loss:8.350883
# ounty; bods. wid in a porof the rather frobeninerasot our counly his leather this?
# The modit on connest for famk Alinutal. hoghed weene so morrus? was boln bat, mutthe croble has; go' thomes
# Freend un
#
#
# iter :1239500, loss:8.546452
# maniun? With the rep, leat to corn we'l the cemunirn it we'lovery,
# Ast it my you mave 't stald nower attruce o, tht us gowa'
# Our sun; on he prousa hestet youad-ing ay to in heedy, sere see are whow
# Or
#
#
# iter :1240000, loss:8.305156
# ok ont wike at of whow date.
#
# First Citizen: I lave tenves munted Cionh outh fim tole the tan in sich, firing, the gord you helust to the reart him:
# Faresthes. Ye?--
#
# MENENIUS:
# Wheed o' the stand it;
#
#
# iter :1240500, loss:8.397363
# n?
# Whe say dow't blot en, the fadie tull, to thom dis do woustel's I pare prearter mort bator vantion
# This accoved on yath hingul; elvam
# Frich a way he be quancl; and fithy Vortith and of you streds.
#
#
#
# iter :1241000, loss:8.187286
#  firmagd,
# To bod, abwan'd chickll a, theme dell goedsudewaroue my,
# And wall hips abowar'ld, thut with his stod us
# Tleanouring must leart to thantes
# Beith, comes and
# plad, the pairs sere himssle on all
#
#
# iter :1241500, loss:8.338018
# igt.
#
# MENENIUS:
# Nomprates our lenesthe shale no acciot.
#
# SICINIUS:
# With to theie, that!
# US:
# Be: you what your hedigh besur,
# One criches nown affet and eiveds,
#
# First Citize so' dear and us Hart; makbe
#
#
# iter :1242000, loss:8.222098
# OMMENIUGUS:
# MAle:
# Bejuand
# Your omed They shoussow do be wauld tanouch; a peving Veod ovecller eneror of the resel'd we got un the firsm, and hali:
# Noblemver Tout tour wele,
# Whang as forter's myswer us
#
#
# iter :1242500, loss:8.236796
# LERENIUS:
# Han,
# Tupin
# forth mundy your citiell, the us, filunghiors Copact them baints'ferfees you comes,
# Ere can nome fruts to you, am spong!-
#
# VOLUMNIA:
# Beitius.
# On
# The winhss,
# Ye!
# Andeds.
#
# First Cit
#
#
# iter :1243000, loss:8.469042
# der if all fathlest, lies.
#
# First Cmaceston
# And varding.
#
# VALERIA:
# InI gaincodile togt shere bese'lsty
# The welidepputios:
# Stenver:
# Your of he are we
# courst Se itwer!
#
# MENENIUS:
# We ray hown,
# Seents for
#
#
# iter :1243500, loss:8.308353
# y. what frue it pres
# 'cemy! wh your doe this then of then?
#
# COMINIUS:
# Nay you be with had in,
# Tho 'houst whe fithing they:
# And Caing hisstrel weed in the usgale for 'gemit to irs kast wingus gragh: ou
#
#
# iter :1244000, loss:8.357545
#  is coulanimelucan make Marcid, and till, pelfelved firmwneans in the makeseate lyeren this blito you de all his freat un rece all grevedirf in hown?
#
# MENENIUS:
# Out evemorr:
# I you badives Justinous'do
#
#
# iter :1244500, loss:8.187232
# . For thenes are
# Speal by pake is, in out then were resand sent his presuartss, their neve nave to these vanees for is atting. To bvougher lutwhy, wisswaves a gotfer.
#
# VOLUMNIA:
# Be, I nobles your wes
#
#
# iter :1245000, loss:8.261404
#  wase qrow rim napaior:
# Hatton our swrow treaks the waruan; I, I lead afneanty.
# Fortittthe are bet and itclator: nga'd to ay sendest: this craves onves bus was arms' god us googhes.
# To do sung forel
#
#
# iter :1245500, loss:8.194858
# tetherarning counton sent: Madam, tho'
# Whel?
#
# First Come nourll en,
# I varn us reserves, I the homs 'twelf they--
# MToCINIUS:
# Awny, our wal the greres
# Hourtny ally Marcius.
#
# MENENIUS:
# The ressarusely an
#
#
# iter :1246000, loss:8.221448
# ut make first esvimy you dot ho
# MARUCOMINIUS:
# 'Tod they, we madatrse?
#
# MIRGILaR:
# What, theyed you
# Ore: what he
# Marse, lor thif yiards: hing you'll.
#
# First I, Ilt, thought he so stry's not, they thesen
#
#
# iter :1246500, loss:8.458356
# e con to frow he arof'll his
# treist?
#
# MENENIUS:
# Eichives of there answor ance a grusdow a arabust belly Marcius, that that, our hith and for I munt Ceeatielviged liking. You'.'
#
# Secouth dich the brain
#
#
# iter :1247000, loss:8.288818
# reves, whoy
# Whe elitung ane a grem at if. peid a fitte are in,
# it wasidely were pay and comsons?
#
# MARCIUS:
# For in hartide,
# That, from ove know this
# Of you,
# We preard Citizen:
# Shouns houge there good
# C
#
#
# iter :1247500, loss:8.125244
# ies and camoprriant.
# The bedse, knot the come, spluad frel us more anl resone to thiss, thiom!
# The one
# Haple, the conce lott opjlin-
# That rece,
# Had, not toms are are say
# And it: out rase,
# Youlived her
#
#
# iter :1248000, loss:7.885107
# d Cay, senter that cailly seneary, bake's et eate fio, spie, what yout one Cominiss,
# As hame your momested the gratert, well.
#
# First Citizen:
# Mor meselve to the raved ber, whe? grees sore: his
# made, a
#
#
# iter :1248500, loss:7.676438
# d, it are think now made than peton
# They react. Will Roma ritiSe the goeds,
# Pack sid with me looked
# Calemer diop!
# Brewour lead thustay il the grareatilith most the brone to we, felp abling is,
# Or youc
#
#
# iter :1249000, loss:7.648188
# bse;
# To March,
#
# MENENIUS:
# Hely. What tiiuss, As, If the tho us to to the modes a repown
# commonoun the store it onlies?'
# Wh? make a senserce;
# Yout whusty they veres of you to they heag I I chance sen h
#
#
# iter :1249500, loss:7.569836
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_32480/1057934024.py in <module>
#       3 data_reader = DataReader("input1.txt", seq_length)
#       4 rnn = RNN(hidden_size=100, vocab_size=data_reader.vocab_size,seq_length=seq_length,learning_rate=1e-1)
# ----> 5 rnn.train(data_reader)
#       6
#       7
#
# ~\AppData\Local\Temp/ipykernel_32480/2607019164.py in train(self, data_reader)
#     106                 inputs, targets = data_reader.next_batch()
#     107                 xs, hs, ps = self.forward(inputs, hprev)
# --> 108                 dU, dW, dV, db, dc = self.backward(xs, hs, ps, targets)
#     109                 loss = self.loss(ps, targets)
#     110                 self.update_model(dU, dW, dV, db, dc)
#
# ~\AppData\Local\Temp/ipykernel_32480/2607019164.py in backward(self, xs, hs, ps, targets)
#      61             # clip to mitigate exploding gradients
#      62             for dparam in [dU, dW, dV, db, dc]:
# ---> 63                 np.clip(dparam, -5, 5, out=dparam)
#      64             return dU, dW, dV, db, dc
#      65
#
# <__array_function__ internals> in clip(*args, **kwargs)
#
# ~\PycharmProjects\pythonProject\venv\lib\site-packages\numpy\core\fromnumeric.py in clip(a, a_min, a_max, out, **kwargs)
#    2113
#    2114     """
# -> 2115     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
#    2116
#    2117
#
# ~\PycharmProjects\pythonProject\venv\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      55
#      56     try:
# ---> 57         return bound(*args, **kwds)
#      58     except TypeError:
#      59         # A TypeError occurs if the object does have such a method in its
#
# ~\PycharmProjects\pythonProject\venv\lib\site-packages\numpy\core\_methods.py in _clip(a, min, max, out, casting, **kwargs)
#     157             um.maximum, a, min, out=out, casting=casting, **kwargs)
#     158     else:
# --> 159         return _clip_dep_invoke_with_casting(
#     160             um.clip, a, min, max, out=out, casting=casting, **kwargs)
#     161
#
# ~\PycharmProjects\pythonProject\venv\lib\site-packages\numpy\core\_methods.py in _clip_dep_invoke_with_casting(ufunc, out, casting, *args, **kwargs)
#     111     # try to deal with broken casting rules
#     112     try:
# --> 113         return ufunc(*args, out=out, **kwargs)
#     114     except _exceptions._UFuncOutputCastingError as e:
#     115         # Numpy 1.17.0, 2019-02-24
#
# KeyboardInterrupt:

# %%
rnn.predict(data_reader, 'get', 50)
